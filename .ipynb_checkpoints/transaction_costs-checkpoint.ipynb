# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
url = "https://api.worldbank.org/v2/country/ARE/indicator/SI.RMT.COST.IB.ZS?format=json&per_page=100"
response = requests.get(url)
data = response.json()

# %%
print(len(data))
print(data[0])
# Out:
# 2
# {'page': 1, 'pages': 1, 'per_page': 100, 'total': 66, 'sourceid': '2', 'lastupdated': '2026-07-13'}

# %%
print(data[1][0])
print(data[1][1])
# Out:
# {'indicator': {'id': 'SI.RMT.COST.IB.ZS', 'value': 'Average transaction cost of sending remittances to a specific country (%)'}, 'country': {'id': 'AE', 'value': 'United Arab Emirates'}, 'countryiso3code': 'ARE', 'date': '2025', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 2}
# {'indicator': {'id': 'SI.RMT.COST.IB.ZS', 'value': 'Average transaction cost of sending remittances to a specific country (%)'}, 'country': {'id': 'AE', 'value': 'United Arab Emirates'}, 'countryiso3code': 'ARE', 'date': '2024', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 2}

# %%
etherscan_api_key = "6TTZ63VQH6ZQI5NFDPTW5DCDI9SD8XXX9D"

# %%
usdc_contract = "0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48"
url = f"https://api.etherscan.io/v2/api?chainid=1&module=account&action=tokentx&contractaddress={usdc_contract}&page=1&offset=1000&sort=desc&apikey={etherscan_api_key}"
response = requests.get(url)
eth_data = response.json()

# %%
print(eth_data['status'])
print(eth_data['message'])
print(eth_data['result'][0])
# Out:
# 1
# OK
# {'blockNumber': '25817757', 'timeStamp': '1787486891', 'hash': '0x70d9ecea7ea0f989552356329471bfca111a7f833917d99b1d90c4a06d329f3a', 'nonce': '5', 'blockHash': '0x34f76ebc8c2141886072611853153ecc78637619ca4300a4ed328b475d345390', 'from': '0xa2541f06538795fd201ae08c1cafd185d39bf1dc', 'contractAddress': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'to': '0x4d5fa1839aed8dce51c5fe3bc23f4fc08e02702e', 'value': '98910000', 'tokenName': 'USDC', 'tokenSymbol': 'USDC', 'tokenDecimal': '6', 'transactionIndex': '188', 'gas': '45758', 'gasPrice': '97652126', 'gasUsed': '40360', 'cumulativeGasUsed': '22317202', 'input': 'deprecated', 'methodId': '0xa9059cbb', 'functionName': 'transfer(address _to, uint256 _value)', 'confirmations': '2', 'statusRep': '1'}

# %%
print(eth_data)
# Out:
# {'status': '1', 'message': 'OK', 'result': [{'blockNumber': '25817757', 'timeStamp': '1787486891', 'hash': '0x70d9ecea7ea0f989552356329471bfca111a7f833917d99b1d90c4a06d329f3a', 'nonce': '5', 'blockHash': '0x34f76ebc8c2141886072611853153ecc78637619ca4300a4ed328b475d345390', 'from': '0xa2541f06538795fd201ae08c1cafd185d39bf1dc', 'contractAddress': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'to': '0x4d5fa1839aed8dce51c5fe3bc23f4fc08e02702e', 'value': '98910000', 'tokenName': 'USDC', 'tokenSymbol': 'USDC', 'tokenDecimal': '6', 'transactionIndex': '188', 'gas': '45758', 'gasPrice': '97652126', 'gasUsed': '40360', 'cumulativeGasUsed': '22317202', 'input': 'deprecated', 'methodId': '0xa9059cbb', 'functionName': 'transfer(address _to, uint256 _value)', 'confirmations': '2', 'statusRep': '1'}, {'blockNumber': '25817757', 'timeStamp': '1787486891', 'hash': '0xefea3ff04c64ed9982fa00ce02a28fe43df61ad4180dec242ba7e4a381cf684c', 'nonce': '4310', 'blockHash': '0x34f76ebc8c2141886072611853153ecc78637619ca4300a4ed328b475d345390', 'from': '0x2e5a051e8b4aa852332277d817a6d7adcbbefa94', 'contractAddress': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'to': '0x4cd00e387622c35bddb9b4c962c136462338bc31', 'value': '95966226', 'tokenName': 'USDC', 'tokenSymbol': 'USDC', 'tokenDecimal': '6', 'transactionIndex': '184', 'gas': '767193', 'gasPrice': '3583344608', 'gasUsed': '469250', 'cumulativeGasUsed': '22213842', 'input': 'deprecated', 'methodId': '0xc3c16ee4', 'functionName': '', 'confirmations': '2', 'statusRep': '1'}, {'blockNumber': '25817757', 'timeStamp': '1787486891', 'hash': '0xefea3ff04c64ed9982fa00ce02a28fe43df61ad4180dec242ba7e4a381cf684c', 'nonce': '4310', 'blockHash': '0x34f76ebc8c2141886072611853153ecc78637619ca4300a4ed328b475d345390', 'from': '0x6cb7318d44859533da6d440f1e76b5568fa33ddc', 'contractAddress': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'to': '0x2e5a051e8b4aa852332277d817a6d7adcbbefa94', 'value': '95966226', 'tokenName': 'USDC', 'tokenSymbol': 'USDC', 'tokenDecimal': '6', 'transactionIndex': '184', 'gas': '767193', 'gasPrice': '3583344608', 'gasUsed': '469250', 'cumulativeGasUsed': '22213842', 'input': 'deprecated', 'methodId': '0xc3c16ee4', 'functionName': '', 'confirmations': '2', 'statusRep': '1'}, {'blockNumber': '25817757', 'timeStamp': '1787486891', 'hash': '0xefea3ff04c64ed9982fa00ce02a28fe43df61ad4180dec242ba7e4a381cf684c', 'nonce': '4310', 'blockHash': '0x34f76ebc8c2141886072611853153ecc78637619ca4300a4ed328b475d345390', 'from': '0xf9280799c85d376e0425f6fb38e4a674e8bedb56', 'contractAddress': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'to': '0x6cb7318d44859533da6d440f1e76b5568fa33ddc', 'value': '95966226', 'tokenName': 'USDC', 'tokenSymbol': 'USDC', 'tokenDecimal': '6', 'transactionIndex': '184', 'gas': '767193', 'gasPrice': '3583344608', 'gasUsed': '469250', 'cumulativeGasUsed': '22213842', 'input': 'deprecated', 'methodId': '0xc3c16ee4', 'functionName': '', 'confirmations': '2', 'statusRep': '1'}, {'blockNumber': '25817757', 'timeStamp': '1787486891', 'hash': '0xefea3ff04c64ed9982fa00ce02a28fe43df61ad4180dec242ba7e4a381cf684c', 'nonce': '4310', 'blockHash': '0x34f76ebc8c2141886072611853153ecc78637619ca4300a4ed328b475d345390', 'from': '0xf9280799c85d376e0425f6fb38e4a674e8bedb56', 'contractAddress': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'to': '0x7e7df6f60581f13216c5e6fcfc5643b9f4261750', 'value': '96062', 'tokenName': 'USDC', 'tokenSymbol': 'USDC', 'tokenDecimal': '6', 'transactionIndex': '184', 'gas': '767193', 'gasPrice': '3583344608', 'gasUsed': '469250', 'cumulativeGasUsed': '22213842', 'input': 'deprecated', 'methodId': '0xc3c16ee4', 'functionName': '', 'confirmations': '2', 'statusRep': '1'}, {'blockNumber': '25817757', 'timeStamp': '1787486891', 'hash': '0xefea3ff04c64ed9982fa00ce02a28fe43df61ad4180dec242ba7e4a381cf684c', 'nonce': '4310', 'blockHash': '0x34f76ebc8c2141886072611853153ecc78637619ca4300a4ed328b475d345390', 'from': '0x000000000004444c5dc75cb358380d2e3de08a90', 'contractAddress': '0x ...

# %%
print(len(eth_data['result']))
# Out:
# 1000

# %%
for tx in eth_data['result'][:5]:
    print(tx['gasPrice'])
    print(tx['timeStamp'])

values = [int(tx['value']) for tx in eth_data['result']]
print(max(values))
senders = [tx['from'] for tx in eth_data['result']]
print(len(set(senders)))
# Out:
# 97652126
# 1787486891
# 3583344608
# 1787486891
# 3583344608
# 1787486891
# 3583344608
# 1787486891
# 3583344608
# 1787486891
# 631494939368
# 571

# %%
gas_used = []

for tx in tx_list:
    gas_used.append(int(tx['gasUsed']))

# %%
print(len(gas_used))
print(gas_used[:5])
# Out:
# 1000
# [40360, 469250, 469250, 469250, 469250]

# %%
gas_price = []

for tx in tx_list:
     gas_price.append(int(tx['gasPrice']))

timestamps = []

for tx in tx_list:
     timestamps.append(int(tx['timeStamp']))

# %%
print(len(gas_price))
print(gas_price[:5])

print(len(timestamps))
print(timestamps[:5])
# Out:
# 1000
# [97652126, 3583344608, 3583344608, 3583344608, 3583344608]
# 1000
# [1787486891, 1787486891, 1787486891, 1787486891, 1787486891]

# %%
df = pd.DataFrame({'timestamp': timestamps, 'gas_price_wei': gas_price, 'gas_used': gas_used})

# %%
print(len(gas_used))
print(len(gas_price))
print(len(timestamps))
# Out:
# 1000
# 1000
# 1000

# %%
df['fee_wei'] = df['gas_used'] * df['gas_price_wei']

# %%
print(df[['gas_used', 'gas_price_wei', 'fee_wei']].head())
# Out:
#    gas_used  gas_price_wei           fee_wei
# 0     40360       97652126     3941239805360
# 1    469250     3583344608  1681484457304000
# 2    469250     3583344608  1681484457304000
# 3    469250     3583344608  1681484457304000
# 4    469250     3583344608  1681484457304000

# %%
url = "https://api.coingecko.com/api/v3/simple/price?ids=ethereum&vs_currencies=usd"
response = requests.get(url)
eth_price_data = response.json()
print(eth_price_data)
# Out:
# {'ethereum': {'usd': 2441.78}}

# %%
eth_price_usd = eth_price_data['ethereum']['usd']
print(eth_price_usd)
# Out:
# 2441.78

# %%
df['fee_usd'] = (df['fee_wei'] / 1e18) * eth_price_usd
df['date'] = pd.to_datetime(df['timestamp'], unit='s')

# %%
print(df[['date', 'gas_used', 'fee_usd']].head())
print(df['fee_usd'].describe())
# Out:
#                  date  gas_used   fee_usd
# 0 2026-08-23 12:08:11     40360  0.009624
# 1 2026-08-23 12:08:11    469250  4.105815
# 2 2026-08-23 12:08:11    469250  4.105815
# 3 2026-08-23 12:08:11    469250  4.105815
# 4 2026-08-23 12:08:11    469250  4.105815
# count    1000.000000
# mean        0.688768
# std         2.052203
# min         0.007610
# 25%         0.036186
# 50%         0.173105
# 75%         0.639486
# max        42.549778
# Name: fee_usd, dtype: float64

# %%
values = []
for tx in tx_list:
    values.append(int(tx['value']) / 1_000_000)
df['value_usdc'] = values

# %%
print(df[['value_usdc', 'fee_usd']].describe())
# Out:
#           value_usdc      fee_usd
# count    1000.000000  1000.000000
# mean     5879.800397     0.688768
# std     42742.330919     2.052203
# min         0.000000     0.007610
# 25%         5.187500     0.036186
# 50%        90.655212     0.173105
# 75%       594.811417     0.639486
# max    631494.939368    42.549778

# %%
df['fee_pct_of_value'] = (df['fee_usd'] / df['value_usdc']) * 100
large_txns = df[df['value_usdc'] > 10000]
print(large_txns[['value_usdc', 'fee_usd', 'fee_pct_of_value']].describe())
